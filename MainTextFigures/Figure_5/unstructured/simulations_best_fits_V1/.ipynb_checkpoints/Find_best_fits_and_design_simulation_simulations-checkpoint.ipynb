# %% [markdown]
# # Find best parameters describing data, both combined and separated fits.
# # Then run simulations on the cluster
#
#
# Since most of the fits are chaotic, I repeat simulations multiple times (20).

# %%
# %reset
#%qtconsole
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import matplotlib as mpl
import scipy.stats as stats
import pandas as pd
import functions_optimal as fun
import functions_dynamics as fun_dyna
from scipy.interpolate import interp1d,interp2d

area=4.0;linethicknes=1.0;

font = {'family' : 'normal','weight' : 'normal','size'   : 7, 'family':'serif','serif':['Arial']}
mpl.rc('font', **font)
mpl.rcParams['lines.linewidth'] =linethicknes
mpl.rcParams['text.usetex'] = False
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['mathtext.rm'] = 'serif'
mpl.rcParams['pdf.fonttype'] = 42
area=4.0;linethicknes=1.0;
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Train DNN

# %%
folder='/Users/ale/Dropbox/research/Laser_on_E_cells/Draft_figures_simulations_v2/Figure_7/with_different_CV_K/simulations/'
results=np.loadtxt(folder+'results.txt');
folder='/Users/ale/Dropbox/research/Laser_on_E_cells/Draft_figures_simulations_v2/Figure_7/with_different_CV_K_larger_J_long/simulations/'
results=np.concatenate((results,np.loadtxt(folder+'results.txt')));

sim_param_all=results[:,0:15]
moments_of_r_sim_all=results[:,15:20]

sim_g_E=(sim_param_all[:,2])
sim_g_I=(sim_param_all[:,3])
sim_beta=(sim_param_all[:,4])
sim_CV_K=(sim_param_all[:,7])
sim_sigma_Lambda_over_Lambda=(sim_param_all[:,10])
sim_J=(sim_param_all[:,11])
sim_r_X=(sim_param_all[:,12])
sim_ell=(sim_param_all[:,13])

print(np.shape(results))
# Out:
# (119464, 28)

# %%
# Train DNN
Predictor_sim,Predictor_data=fun.build_function(results)
# Out:
# Test R^2 Score : 0.938
# Training R^2 Score : 0.953

# %%
# Load recordings in mice and monkeys

# %%
data_mice=np.loadtxt('Mice_with_trials.txt');
data_monkeys=np.loadtxt('Monkeys_with_trials.txt');

data_both_species=[data_mice,data_monkeys]
# structure of data set is:
# unit number, contrast, laser, rate, other stuff

dataset_both_species,Con_both_species,nCon_both_species,normalization_both_species=[],[],[],[]
for idx_species in range(2):
    dataset,Con,nCon=fun.build_dataset(data_both_species[idx_species])
    normalization=1.0;#np.mean(dataset[0,:,0])
    dataset_both_species=dataset_both_species+[dataset]
    Con_both_species=Con_both_species+[Con]
    nCon_both_species=nCon_both_species+[nCon]
    normalization_both_species=normalization_both_species+[normalization]

# %%
rows=4
cols=2

colors=['c','m']
fig, axs = plt.subplots(rows,cols, figsize=(2.5*cols,2.*rows), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.5)
axs = axs.ravel()



for idx_species in range(2):
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]

    for idx_moment in range(6):
        if idx_moment<2:
            idx_row=0
            ccc=['k',colors[idx_species]][idx_moment]
            
        if (idx_moment>=2)&(idx_moment<4):
            idx_row=1
            ccc=['k',colors[idx_species]][idx_moment-2]

        if (idx_moment==4):
            idx_row=2
            ccc=colors[idx_species]

        if (idx_moment==5):
            idx_row=3
            ccc=colors[idx_species]
            
        axs[2*idx_row+idx_species].errorbar(Con,dataset[idx_moment,:,0],dataset[idx_moment,:,1],
                                                 color=ccc,)

        axs[2*idx_row+idx_species].set_xscale('symlog', linthreshx=12)

# %% [markdown]
# # Best fit in separated

# %%
nRep=31;
ALL_sol,ALL_cost=[],[]
for idx_species in range(2):
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]
    sol,cost=fun.fit_model_to_data(dataset,Predictor_data,nCon,nRep)
    
    ALL_sol=ALL_sol+[sol]
    ALL_cost=ALL_cost+[cost]
# Out:
# rep= 0  param init= [ 8.11  3.23 -0.77 -3.06  0.05 -3.85]
# [ 8.1   3.23 -0.77 -3.06  0.06 -3.87] 113.09885683457787
# rep= 1  param init= [ 5.14  2.36 -0.74 -3.06 -0.37 -3.4 ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-470191902e29> in <module>
#       6     Con=Con_both_species[idx_species]
#       7     nCon=nCon_both_species[idx_species]
# ----> 8     sol,cost=fun.fit_model_to_data(dataset,Predictor_data,nCon,nRep,input_min,input_max)
#       9
#      10     ALL_sol=ALL_sol+[sol]
#
# ~/Dropbox/research/Laser_on_E_cells/Draft_figures_simulations_v2/Figure_7/simulations/functions_optimal.py in fit_model_to_data(dataset, model, nCon, nRep, input_min, input_max)
#     221     cost=np.zeros(nRep)
#     222     for idx_rep in range(nRep):
# --> 223         print('rep=',idx_rep,' param init=',param_0[idx_rep,:])
#     224         res_2 = least_squares(Residuals, param_0[idx_rep,:],
#     225                           args=(dataset,model,nCon,),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     923
#     924     elif method == 'trf':
# --> 925         result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     926                      gtol, max_nfev, x_scale, loss_function, tr_solver,
#     927                      tr_options.copy(), verbose)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     121             loss_function, tr_solver, tr_options, verbose)
#     122     else:
# --> 123         return trf_bounds(
#     124             fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125             loss_function, tr_solver, tr_options, verbose)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     336
#     337             x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
# --> 338             f_new = fun(x_new)
#     339             nfev += 1
#     340
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py in fun_wrapped(x)
#     810
#     811     def fun_wrapped(x):
# --> 812         return np.atleast_1d(fun(x, *args, **kwargs))
#     813
#     814     if method == 'trf':
#
# ~/Dropbox/research/Laser_on_E_cells/Draft_figures_simulations_v2/Figure_7/simulations/functions_optimal.py in Residuals(param, dataset, model, nCon)
#     191
#     192     def Residuals(param,dataset,model,nCon,):
# --> 193         # residual for fixed parameters
#     194         inputs=fit_inputs_to_data_given_param(dataset,model,param,nCon)
#     195         prediction=model(inputs,param,nCon,)
#
# ~/Dropbox/research/Laser_on_E_cells/Draft_figures_simulations_v2/Figure_7/simulations/functions_optimal.py in fit_inputs_to_data_given_param(dataset, model, param, nCon, input_min, input_max)
#     177     input_0=np.log10(np.linspace(1,5,nCon+1))
#     178
# --> 179     #print(input_0)
#     180     res_2 = least_squares(Residuals_FixedNet, input_0,
#     181                           args=(dataset,model,param,nCon,),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     923
#     924     elif method == 'trf':
# --> 925         result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     926                      gtol, max_nfev, x_scale, loss_function, tr_solver,
#     927                      tr_options.copy(), verbose)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     121             loss_function, tr_solver, tr_options, verbose)
#     122     else:
# --> 123         return trf_bounds(
#     124             fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125             loss_function, tr_solver, tr_options, verbose)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     372             cost = cost_new
#     373
# --> 374             J = jac(x, f)
#     375             njev += 1
#     376
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py in jac_wrapped(x, f)
#     881
#     882             def jac_wrapped(x, f):
# --> 883                 J = approx_derivative(fun, x, rel_step=diff_step, method=jac,
#     884                                       f0=f, bounds=bounds, args=args,
#     885                                       kwargs=kwargs, sparsity=jac_sparsity)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/Dropbox/research/Laser_on_E_cells/Draft_figures_simulations_v2/Figure_7/simulations/functions_optimal.py in Residuals_FixedNet(inputs, dataset, model, param, nCon)
#     170     def Residuals_FixedNet(inputs,dataset,model,param,nCon,):
#     171         # residual for fixed parameters
# --> 172         prediction=model(inputs,param,nCon,)
#     173         prediction[np.isnan(prediction)==True]=10**10
#     174         Residuals=(prediction-dataset[:,:,0])/dataset[:,:,1]
#
# ~/Dropbox/research/Laser_on_E_cells/Draft_figures_simulations_v2/Figure_7/simulations/functions_optimal.py in Predictor_data(inputs, param, nCon)
#     172         prediction=model(inputs,param,nCon,)
#     173         prediction[np.isnan(prediction)==True]=10**10
# --> 174         Residuals=(prediction-dataset[:,:,0])/dataset[:,:,1]
#     175         return Residuals.ravel()
#     176     input_min,input_max=-1,2;
#
# ~/Dropbox/research/Laser_on_E_cells/Draft_figures_simulations_v2/Figure_7/simulations/functions_optimal.py in Predictor_sim(X_test)
#     158         prediction[0,:]=mean_Base
#     159         prediction[1,:]=mean_Base+mean_Delta
# --> 160         prediction[2,:]=std_Base
#     161         prediction[3,:]=np.sqrt(std_Base**2+std_Delta**2+2*cov_Base_Delta)
#     162         prediction[4,:]=std_Delta
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py in predict(self, X)
#    1407         """
#    1408         check_is_fitted(self)
# -> 1409         y_pred = self._forward_pass_fast(X)
#    1410         if y_pred.shape[1] == 1:
#    1411             return y_pred.ravel()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py in _forward_pass_fast(self, X)
#     141         for i in range(self.n_layers_ - 1):
#     142             activation = safe_sparse_dot(activation, self.coefs_[i])
# --> 143             activation += self.intercepts_[i]
#     144             if i != self.n_layers_ - 2:
#     145                 hidden_activation(activation)
#
# KeyboardInterrupt:

# %%
rows=4
cols=2

colors=['c','m']
fig, axs = plt.subplots(rows,cols, figsize=(2.5*cols,2.*rows), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.5)
axs = axs.ravel()



for idx_species in range(2):
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]
    
    sol=ALL_sol[idx_species]
    cost=ALL_cost[idx_species]
    idx_best=np.argmin(cost)
    best_param=sol[idx_best,:]
    best_cost=cost[idx_best]
    best_inputs=fun.fit_inputs_to_data_given_param(dataset,Predictor_data,best_param,nCon)
    
    Predictions=Predictor_data(best_inputs,best_param,nCon)
    print(['Mice','Monkeys'][idx_species],best_cost)
    print(repr(best_param))
    print(repr(best_inputs))        
    for idx_moment in range(6):
        if idx_moment<2:
            idx_row=0
            ccc=['k',colors[idx_species]][idx_moment]
            ymin=0
            ymax=[25,80][idx_species]
            
        if (idx_moment>=2)&(idx_moment<4):
            idx_row=1
            ccc=['k',colors[idx_species]][idx_moment-2]
            ymin=0
            ymax=[20,60][idx_species]
         
        if (idx_moment==4):
            idx_row=2
            ccc=colors[idx_species]
            ymin=0
            ymax=[20,60][idx_species]
         
        if (idx_moment==5):
            idx_row=3
            ccc=colors[idx_species]
            ymin=-0.75
            ymax=0.25
                     
        m,sem=dataset[idx_moment,:,0],dataset[idx_moment,:,1]
        axs[2*idx_row+idx_species].scatter(Con,m,
                                           facecolors='none', s=10,edgecolors=ccc,marker='o'
                                           )
        axs[2*idx_row+idx_species].fill_between(Con,m-sem,m+sem,
                                                 color=ccc,alpha=0.2)
    
        axs[2*idx_row+idx_species].plot(Con,Predictions[idx_moment,:],
                                        color=ccc,alpha=1.)

        axs[2*idx_row+idx_species].set_xscale('symlog', linthreshx=12)
        axs[2*idx_row+idx_species].set_ylim([ymin,ymax])
    axs[2*idx_row+idx_species].axhline(y=0,ls='--',c='k')
# Out:
# Mice 1.0439296013882977
# array([ 6.23,  4.9 , -1.  , -3.08, -0.16, -4.14])
# array([1.18, 1.22, 1.24, 1.26, 1.28, 1.38, 1.52, 0.54])
# Monkeys 4.241906852061792
# array([ 7.29,  3.51, -0.19, -1.8 ,  0.65, -2.85])
# array([1.18, 1.48, 1.56, 1.62, 1.64, 1.68, 1.24])

# %% [markdown]
# # Combined

# %%
nRep=31;
DATA_both_species=[dataset_both_species,Con_both_species,nCon_both_species,normalization_both_species]
CMB_sol,CMB_cost=fun.fit_model_to_data_both_species(DATA_both_species,Predictor_data,nCon,nRep)
# Out:
# rep= 0  param init= [ 4.41  2.07 -0.64 -0.88 -0.82 -4.54]
# [ 6.28  2.14 -0.91 -1.08 -0.11 -4.3 ] 186.42503201938314
# rep= 1  param init= [ 6.53  2.42 -0.45 -0.88 -0.67 -4.81]
# [ 6.53  2.42 -0.45 -0.88 -0.67 -4.81] 638.5610435131348
# rep= 2  param init= [ 7.66  2.93 -0.82 -0.88 -0.57 -3.44]
# [ 6.89  2.83 -0.71 -1.27 -0.12 -3.98] 130.0295582411876
# rep= 3  param init= [ 5.99  4.92 -0.74 -0.88  0.5  -4.03]
# [ 7.64  5.69 -0.35 -0.98  0.74 -4.17] 34.86737469266116
# rep= 4  param init= [ 9.62  2.49 -0.79 -0.88 -0.07 -4.97]
# [ 9.25  3.   -0.71 -0.67  0.34 -4.53] 60.9994069907321
# rep= 5  param init= [ 8.29  5.48 -0.11 -0.88 -0.84 -3.61]
# [ 7.61  6.34 -0.49 -1.79  0.2  -3.69] 31.622957408066867
# rep= 6  param init= [ 9.27  8.49 -0.06 -0.88  0.47 -3.07]
# [ 8.72  8.01 -0.18 -1.47  0.51 -2.89] 55.819834118250526
# rep= 7  param init= [ 9.65  7.12 -0.77 -0.88 -0.11 -4.73]
# [ 8.6   5.65 -0.5  -0.95  0.37 -4.31] 45.48032956941647
# rep= 8  param init= [ 5.18  2.35 -0.55 -0.88 -0.19 -3.34]
# [ 4.92  2.22 -0.47 -1.34  0.04 -3.49] 116.1782610524266
# rep= 9  param init= [ 7.54  4.54 -0.85 -0.88  0.12 -3.2 ]
# [ 3.69  3.99 -0.76 -1.66  0.45 -3.24] 32.13465433188322
# rep= 10  param init= [ 9.    5.9  -0.35 -0.88 -0.59 -4.47]
# [ 8.17  5.63 -0.5  -1.24  0.25 -4.08] 43.333518885640075
# rep= 11  param init= [ 5.65  3.04 -0.28 -0.88 -0.93 -4.83]
# [ 6.75  3.59 -0.13 -1.09 -0.31 -4.56] 521.6454490351161
# rep= 12  param init= [ 3.55  2.57 -0.3  -0.88  0.03 -3.38]
# [ 3.29  2.01 -0.17 -1.37  0.55 -3.53] 33.82039611519589
# rep= 13  param init= [ 6.74  3.96 -0.76 -0.88 -0.99 -3.28]
# [ 6.59  4.   -0.76 -0.93 -0.99 -3.34] 343.843027412257
# rep= 14  param init= [ 4.17  3.19 -0.78 -0.88 -0.84 -3.65]
# [ 4.39  3.65 -0.46 -1.66 -0.16 -3.23] 42.754514242174544
# rep= 15  param init= [ 3.17  2.21 -0.49 -0.88 -0.16 -4.4 ]
# [ 3.12  2.33 -0.52 -0.88 -0.12 -4.46] 669.6161942374172
# rep= 16  param init= [ 9.87  5.37 -0.43 -0.88  0.6  -4.88]
# [ 9.87  5.57 -0.42 -0.87  0.69 -4.77] 156.26692766678792
# rep= 17  param init= [ 3.54  2.58 -0.75 -0.88  0.14 -3.96]
# [ 4.19  2.27 -0.57 -1.01  0.2  -4.01] 85.9381008578419
# rep= 18  param init= [ 7.55  5.59 -0.63 -0.88 -0.69 -4.38]
# [ 7.65  6.56 -0.47 -1.77  0.26 -3.75] 30.96278477741714
# rep= 19  param init= [ 5.55  4.45 -0.47 -0.88 -0.91 -3.97]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] 14.688882767293821
# rep= 20  param init= [ 7.63  5.4  -0.28 -0.88 -0.42 -3.01]
# [ 7.33  3.9  -0.42 -1.74 -0.24 -3.08] 34.0891120221916
# rep= 21  param init= [ 5.27  3.37 -0.73 -0.88  0.15 -4.05]
# [ 6.92  5.23 -0.4  -0.99  0.65 -4.14] 38.2077569380978
# rep= 22  param init= [ 9.84  9.06 -0.24 -0.88  0.77 -3.83]
# [ 9.96  8.35 -0.19 -0.93  0.79 -4.34] 34.54660590429363
# rep= 23  param init= [ 6.88  4.58 -0.81 -0.88 -0.85 -4.9 ]
# [ 8.21  5.28 -0.63 -1.01 -0.22 -4.28] 68.71867510844103
# rep= 24  param init= [ 5.52  4.46 -0.46 -0.88  0.63 -4.54]
# [ 7.12  5.49 -0.31 -0.86  0.87 -4.24] 35.36872664057776
# rep= 25  param init= [ 7.61  2.05 -0.77 -0.88  0.86 -4.6 ]
# [ 7.17  2.47 -0.79 -0.8   0.87 -4.34] 59.05836920384424
# rep= 26  param init= [ 4.17  2.06 -0.14 -0.88 -0.93 -3.81]
# [ 5.04  3.36 -0.57 -0.99  0.18 -4.1 ] 68.56966348106502
# rep= 27  param init= [ 7.28e+00  3.71e+00 -1.22e-03 -8.83e-01 -5.75e-01 -4.39e+00]
# [ 7.27  3.72 -0.02 -0.88 -0.56 -4.39] 531.2391536543228
# rep= 28  param init= [ 9.99  6.3  -0.73 -0.88  0.08 -4.7 ]
# [ 9.96  6.61 -0.44 -0.86  0.28 -4.49] 59.19071535883501
# rep= 29  param init= [ 3.7   2.09 -0.34 -0.88 -0.03 -4.49]
# [ 4.    2.   -0.37 -0.83 -0.02 -4.59] 646.6443863206558
# rep= 30  param init= [ 6.06  5.26 -0.24 -0.88  0.46 -4.04]
# [ 6.02  5.   -0.23 -0.9   0.46 -4.05] 121.18417781208277

# %%
rows=4
cols=2

colors=['c','m']
fig, axs = plt.subplots(rows,cols, figsize=(2.5*cols,2.*rows), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.5)
axs = axs.ravel()



for idx_species in range(2):
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]
    normalization=normalization_both_species[idx_species] 

    idx_best=np.argsort(CMB_cost)[0]
    best_param=CMB_sol[idx_best,:]
    best_cost=CMB_cost[idx_best]
    best_inputs=fun.fit_inputs_to_data_given_param(dataset,Predictor_data,best_param,nCon)

    
    Predictions=Predictor_data(best_inputs,best_param,nCon)
    print(['Mice','Monkeys'][idx_species],best_cost)
    print(repr(best_param))
    print(repr(best_inputs))        
    for idx_moment in range(6):
        if idx_moment<2:
            idx_row=0
            ccc=['k',colors[idx_species]][idx_moment]
            ymin=0
            ymax=[25,80][idx_species]
            
        if (idx_moment>=2)&(idx_moment<4):
            idx_row=1
            ccc=['k',colors[idx_species]][idx_moment-2]
            ymin=0
            ymax=[20,60][idx_species]
         
        if (idx_moment==4):
            idx_row=2
            ccc=colors[idx_species]
            ymin=0
            ymax=[20,60][idx_species]
         
        if (idx_moment==5):
            idx_row=3
            ccc=colors[idx_species]
            ymin=-0.75
            ymax=0.25
                     
        m,sem=dataset[idx_moment,:,0],dataset[idx_moment,:,1]
        axs[2*idx_row+idx_species].scatter(Con,m,
                                           facecolors='none', s=10,edgecolors=ccc,marker='o'
                                           )
        axs[2*idx_row+idx_species].fill_between(Con,m-sem,m+sem,
                                                 color=ccc,alpha=0.2)
    
        axs[2*idx_row+idx_species].plot(Con,Predictions[idx_moment,:],
                                        color=ccc,alpha=1.)

        axs[2*idx_row+idx_species].set_xscale('symlog', linthreshx=12)
        axs[2*idx_row+idx_species].set_ylim([ymin,ymax])
    axs[2*idx_row+idx_species].axhline(y=0,ls='--',c='k')
# Out:
# Mice 14.688882767293821
# array([ 7.86,  6.92, -0.33, -1.72,  0.86, -3.83])
# array([ 0.91,  0.95,  0.96,  0.99,  1.  ,  1.1 ,  1.24, -0.22])
# Monkeys 14.688882767293821
# array([ 7.86,  6.92, -0.33, -1.72,  0.86, -3.83])
# array([1.3 , 1.53, 1.62, 1.68, 1.7 , 1.7 , 0.71])

# %%
10**1.7
# Out:
# 50.11872336272722

# %% [markdown]
# # Create data array

# %%
Tmax_over_tau_E=2*10**2
n_rep=20;

sigma_t=0.01; 
tau_rp=0.002;

# %%
count=0;
for idx_rep in range(n_rep):
    for idx_combined in range(2):
        for idx_species in range(2):
            dataset=dataset_both_species[idx_species]
            Con=Con_both_species[idx_species]
            nCon=nCon_both_species[idx_species]
            normalization=normalization_both_species[idx_species] 
            if idx_combined==0:
                # best fit combined
                sol=ALL_sol[idx_species]
                cost=ALL_cost[idx_species]
                idx_best=np.argmin(cost)
                best_param=sol[idx_best,:]
            if idx_combined==1:
                # best fit in mice or monkeys
                idx_best=np.argmin(CMB_cost)
                best_param=CMB_sol[idx_best,:]
                best_cost=CMB_cost[idx_best]


            best_inputs=fun.fit_inputs_to_data_given_param(dataset,Predictor_data,best_param,nCon)

            print(best_param,best_inputs)

            Possible_r_X=10**best_inputs[0:-1]
            ell=10**best_inputs[-1]

            g_E= best_param[0]; g_I=best_param[1];beta=10**best_param[2]; 
            K=500; 
            CV_K=10**best_param[3]
            sigma_Lambda_over_Lambda=10**best_param[4];
            J=10**best_param[5];
            for idx_r_X in range(len(Possible_r_X)):
                r_X=Possible_r_X[idx_r_X];

                data=np.ones((1,14));
                data[:,0]=J
                data[:,1]=r_X
                data[:,2]=sigma_Lambda_over_Lambda
                data[:,3]=Tmax_over_tau_E
                data[:,4]=sigma_t
                data[:,5]=tau_rp
                data[:,6]=g_E 
                data[:,7]=g_I
                data[:,8]=beta
                data[:,9]=K
                data[:,10]=ell
                data[:,11]=CV_K
                data[:,12]=idx_species
                data[:,13]=idx_combined

                if count==0:
                    DATA=data;
                if count>0:
                    DATA=np.vstack((DATA,data));
                count=count+1

len(DATA)
# Out:
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# [ 6.23  4.9  -1.   -3.08 -0.16 -4.14] [1.18 1.22 1.24 1.26 1.28 1.38 1.52 0.54]
# [ 7.29  3.51 -0.19 -1.8   0.65 -2.85] [1.18 1.48 1.56 1.62 1.64 1.68 1.24]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [ 0.91  0.95  0.96  0.99  1.    1.1   1.24 -0.22]
# [ 7.86  6.92 -0.33 -1.72  0.86 -3.83] [1.3  1.53 1.62 1.68 1.7  1.7  0.71]
# 520

# %%
df = pd.DataFrame(DATA,columns=['J','r_X','sigma_Lambda_over_Lambda','Tmax_over_tau_E','sigma_t','tau_rp',
                                'g_E','g_I','beta','K','ell','CV_K','idx_species','idx_combined'])
file_name='simulation_param.txt'
df.to_csv(file_name, sep='\t')

# %%
len(DATA)
# Out:
# 520

# %% [markdown]
# # simulation parameters to explore best fits combined

# %%
count=0;
for idx_rep in range(n_rep):
    for idx_combined in range(10):
        for idx_species in range(2):
            dataset=dataset_both_species[idx_species]
            Con=Con_both_species[idx_species]
            nCon=nCon_both_species[idx_species]
            normalization=normalization_both_species[idx_species] 

            idx_best=np.argsort(CMB_cost)[idx_combined]
            best_param=CMB_sol[idx_best,:]
            best_cost=CMB_cost[idx_best]
            print(best_cost)



            best_inputs=fun.fit_inputs_to_data_given_param(dataset,Predictor_data,best_param,nCon)

            print(best_param,best_inputs)

            Possible_r_X=10**best_inputs[0:-1]
            ell=10**best_inputs[-1]

            g_E= best_param[0]; g_I=best_param[1];beta=10**best_param[2]; 
            K=500; 
            CV_K=10**best_param[3]
            sigma_Lambda_over_Lambda=10**best_param[4];
            J=10**best_param[5];
            for idx_r_X in range(len(Possible_r_X)):
                r_X=Possible_r_X[idx_r_X];

                data=np.ones((1,14));
                data[:,0]=J
                data[:,1]=r_X
                data[:,2]=sigma_Lambda_over_Lambda
                data[:,3]=Tmax_over_tau_E
                data[:,4]=sigma_t
                data[:,5]=tau_rp
                data[:,6]=g_E 
                data[:,7]=g_I
                data[:,8]=beta
                data[:,9]=K
                data[:,10]=ell
                data[:,11]=CV_K
                data[:,12]=idx_species
                data[:,13]=idx_combined

                if count==0:
                    DATA=data;
                if count>0:
                    DATA=np.vstack((DATA,data));
                count=count+1

len(DATA)
# Out:
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [0.62 0.67 0.69 0.7  0.71 0.79 0.95 0.61]
# 0.5504457434749176
# [ 6.73  5.79 -0.46 -1.67  0.46 -3.  ] [1.19 1.45 1.53 1.59 1.62 1.64 1.4 ]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [0.45 0.48 0.5  0.51 0.51 0.66 0.9  0.44]
# 0.5752568033294958
# [ 4.89  3.85 -0.09 -1.86  0.28 -3.  ] [1.07 1.4  1.48 1.54 1.58 1.6  1.18]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [0.61 0.64 0.67 0.68 0.67 0.78 1.04 1.09]
# 0.600033359943098
# [ 7.70e+00  4.67e+00 -5.24e-01 -1.72e+00  9.04e-04 -3.00e+00] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [0.61 0.64 0.67 0.68 0.66 0.78 1.03 1.11]
# 0.6005249926491292
# [ 7.95  5.02 -0.51 -1.74 -0.01 -3.  ] [1.19 1.52 1.61 1.65 1.68 1.7  1.7 ]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [0.62 0.64 0.67 0.69 0.7  0.85 1.06 0.54]
# 0.7441508630140412
# [ 3.9   2.79 -0.18 -1.91 -0.02 -3.29] [1.23 1.51 1.59 1.66 1.69 1.7  1.07]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [0.48 0.52 0.53 0.54 0.54 0.7  1.03 0.28]
# 0.9326531178413491
# [10.    2.21 -0.09 -1.72  0.22 -3.  ] [1.14 1.42 1.5  1.56 1.6  1.63 1.42]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [ 0.47  0.54  0.56  0.57  0.56  0.7   0.99 -0.29]
# 0.9484573048815802
# [10.    2.73 -0.03 -1.74  0.86 -3.  ] [1.12 1.41 1.5  1.56 1.6  1.62 1.03]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [0.77 0.81 0.82 0.84 0.82 0.92 1.1  0.24]
# 1.0030408632239494
# [ 4.97  3.2  -0.56 -1.6   0.39 -3.36] [1.27 1.5  1.57 1.62 1.66 1.68 1.08]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [0.93 0.96 0.97 0.99 0.99 1.08 1.26 0.22]
# 1.2433024811998896
# [ 9.96  6.93 -0.71 -1.68  0.39 -4.13] [1.35 1.65 1.7  1.7  1.7  1.7  0.89]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [0.78 0.81 0.84 0.85 0.84 0.93 1.13 0.48]
# 1.2964829316066693
# [ 4.13  2.53 -0.53 -1.64  0.09 -3.31] [1.34 1.53 1.61 1.66 1.7  1.7  1.21]
# 2600

# %%
df = pd.DataFrame(DATA,columns=['J','r_X','sigma_Lambda_over_Lambda','Tmax_over_tau_E','sigma_t','tau_rp',
                                'g_E','g_I','beta','K','ell','CV_K','idx_species','idx_combined'])
file_name='simulation_param.txt'
df.to_csv(file_name, sep='\t')

# %%
len(DATA)
# Out:
# 2600
