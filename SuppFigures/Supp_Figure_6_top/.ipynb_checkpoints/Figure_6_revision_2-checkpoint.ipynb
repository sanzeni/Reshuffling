# %% [markdown]
# # Figure 6 revision

# %%
# %reset
#%qtconsole
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
import matplotlib as mpl
import scipy.stats as stats
from scipy.interpolate import interp1d
import os
import functions_optimal as fun

from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,mark_inset)

area=4.0;linethicknes=1.0;

font = {'family' : 'normal','weight' : 'normal','size'   : 7, 'family':'serif','serif':['Arial']}
mpl.rc('font', **font)
mpl.rcParams['lines.linewidth'] =linethicknes
mpl.rcParams['text.usetex'] = False
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['mathtext.rm'] = 'serif'
mpl.rcParams['pdf.fonttype'] = 42

folder_main='/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/'

data_mice=np.loadtxt(folder_main+'Figure_2/V2/Mice_with_trials.txt');
data_monkeys=np.loadtxt(folder_main+'Figure_2/V2/Monkeys_with_trials.txt');

data_both_species=[data_mice,data_monkeys]
# structure of data set is:
# unit number, contrast, laser, rate, other stuff

dataset_both_species,Con_both_species,nCon_both_species,normalization_both_species=[],[],[],[]
for idx_species in range(2):
    dataset,Con,nCon=fun.build_dataset(data_both_species[idx_species])
    normalization=1.0;#np.mean(dataset[0,:,0])
    dataset_both_species=dataset_both_species+[dataset]
    Con_both_species=Con_both_species+[Con]
    nCon_both_species=nCon_both_species+[nCon]
    
    
species=['Mice','Monkeys']
colors=['c','m']

#results=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/network_simulations/simulate_best_fits_vs_J_done_1/results.txt');
#results=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/network_simulations/simulate_best_fits_vs_J_done_2/results.txt');
#results=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/network_simulations/simulate_best_fits_vs_J_done_3/results.txt');
#results=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/network_simulations/simulate_best_fits_vs_J_done_4/results.txt');
#results=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/network_simulations/simulate_best_fits_vs_J_done_5/results.txt');
#results=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/network_simulations/simulate_best_fits_vs_J_done_6/results.txt');
#results=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/network_simulations/simulate_best_fits_vs_J_done_7/results.txt');
results=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/network_simulations/simulate_best_fits_vs_J/results.txt');

sim_param_all=results[:,0:15]
moments_of_r_sim_all=results[:,15:20]
sim_convergence_all=results[:,20:24]
sim_decay_all=results[:,26]/results[:,27]
sim_species=results[:,28]
sim_idx_J=results[:,29]

sim_curr_E=results[:,30]
sim_curr_I=results[:,31]
sim_curr_tot=results[:,32]
sim_curr_opto=results[:,33]

Possible_Tmax_over_tau_E=np.unique(sim_param_all[:,14])
Possible_sigma_Lambda_over_Lambda=np.unique(sim_param_all[:,10])
Possible_r_X=np.unique(sim_param_all[:,12])
Possible_J=np.unique(sim_param_all[:,11])


results_specific_Js=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/improve_fits_of_specific_Js/simulate_improve_fits_of_specific_Js/results.txt');

sim_param_all_Js=results_specific_Js[:,0:15]
moments_of_r_sim_all_Js=results_specific_Js[:,15:20]
sim_convergence_all_Js=results_specific_Js[:,20:24]
sim_decay_all_Js=results_specific_Js[:,26]/results_specific_Js[:,27]
sim_species_Js=results_specific_Js[:,28]
sim_idx_J_Js=results_specific_Js[:,29]

sim_curr_E_Js=results_specific_Js[:,30]
sim_curr_I_Js=results_specific_Js[:,31]
sim_curr_tot_Js=results_specific_Js[:,32]
sim_curr_opto_Js=results_specific_Js[:,33]



results_specific_Js_mice=np.loadtxt('/Users/ale/Research/Projects/Laser_on_E_cells/Draft_figures_simulations_v2/SI_best_fit_vs_J/V3_Tuan/improve_fits_of_specific_Js_mice/simulate_improve_fits_of_specific_Js_mice/results.txt');
sim_param_all_Js_mice=results_specific_Js_mice[:,0:15]
moments_of_r_sim_all_Js_mice=results_specific_Js_mice[:,15:20]
sim_convergence_all_Js_mice=results_specific_Js_mice[:,20:24]
sim_decay_all_Js_mice=results_specific_Js_mice[:,26]/results_specific_Js_mice[:,27]
sim_species_Js_mice=results_specific_Js_mice[:,28]
sim_idx_J_Js_mice=results_specific_Js_mice[:,29]
sim_curr_E_Js_mice=results_specific_Js_mice[:,30]
sim_curr_I_Js_mice=results_specific_Js_mice[:,31]
sim_curr_tot_Js_mice=results_specific_Js_mice[:,32]
sim_curr_opto_Js_mice=results_specific_Js_mice[:,33]


results_stc=[np.loadtxt('structured_model/vary_J-animal_mouse.txt'),
            np.loadtxt('structured_model/vary_J-animal_monkey.txt'),
            ];

best_J_unstruct=[0.00013,0.000525]
best_J_struct=[0.001*0.093,0.001*0.526]
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
idx_cnt_to_plot=-1

rows=1;cols=4;
fig, axs = plt.subplots(rows,cols, figsize=(2.5*cols,2.*rows), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.5)
area=4.0;linethicknes=1.0;
axs = axs.ravel()
font = {'family' : 'normal','weight' : 'normal','size'   : 7, 'family':'serif','serif':['Arial']}
mpl.rc('font', **font)
mpl.rcParams['lines.linewidth'] =linethicknes
mpl.rcParams['text.usetex'] = False
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['mathtext.rm'] = 'serif'
mpl.rcParams['pdf.fonttype'] = 42


for idx in range(rows*cols):
    axs[idx].spines['top'].set_visible(False)
    axs[idx].spines['right'].set_visible(False)
    axs[idx].set_xlabel(r'$J$ (mV)')
    axs[idx].set_xlim([0.01,1])
    
axs[0].text(-.2, 1.2,'A', transform=axs[0].transAxes,fontsize=8, fontweight='bold', va='top', ha='right');
axs[1].text(-.2, 1.2,'B', transform=axs[1].transAxes,fontsize=8, fontweight='bold', va='top', ha='right');
axs[2].text(-.2, 1.2,'C', transform=axs[2].transAxes,fontsize=8, fontweight='bold', va='top', ha='right');
axs[3].text(-.2, 1.2,'D', transform=axs[3].transAxes,fontsize=8, fontweight='bold', va='top', ha='right');

for idx_species in [1]:
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]


    for idx_moment in np.arange(5,7,1):
        if (idx_moment==5):
            panel=axs[0]
            #panel.set_title(['Mice','Monkeys'][idx_species])
            ccc=colors[idx_species]
            ymin=-0.75
            ymax=0.25
            #ymin=-0.75
            #ymax=0.5
            panel.set_ylabel(r'$\rho$')
        if idx_moment<6:
            m,sem=dataset[idx_moment,:,0],dataset[idx_moment,:,1]

        if idx_moment==6:
            panel=axs[1]
            ccc=['k',colors[idx_species]][1]
            ymin=[0,-10][idx_species]
            ymax=[20,20][idx_species]
            #panel.set_title(['Mice','Monkeys'][idx_species])
            panel.set_ylabel('Mean $\Delta$rate\n(spk/s)')
            m,sem=dataset[1,:,0]-dataset[0,:,0],np.sqrt(dataset[1,:,1]**2+dataset[0,:,1]**2) 
                        

        data_y=np.mean(m[idx_cnt_to_plot::])*np.ones(len(Possible_J))
        data_e=np.mean(sem[idx_cnt_to_plot::])*np.ones(len(Possible_J))
        if idx_moment==5:
            panel.plot(Possible_J*10**3,data_y,lw=3,c=ccc,label='data')

        if idx_moment!=5:
            panel.plot(Possible_J*10**3,data_y,
                                               lw=3,c=ccc,
                                               )
        panel.fill_between(Possible_J*10**3,data_y-data_e,data_y+data_e,
                                                 color=ccc,alpha=0.2)

        panel.set_xscale('log')
        panel.axis([0.01,1,ymin,ymax])

    panel.axhline(y=0,ls='--',c='k')
    #panel.set_xlabel(r'$J$ (mV)')

  
indices=np.arange(0,20,1)

for idx_species in [1]:
    if idx_species==0:
        #indices=np.concatenate((np.arange(0,15,1),np.arange(16,19,1)))
        #indices=np.concatenate((np.arange(0,17,1),np.arange(18,19,1)))
        #print(Possible_J[15],Possible_J[17],Possible_J[19])
        indices_Js=[15,17]#[15,17,19]
        indices_Js_mice=[10,11,12,13,14,16,18,19]#[15,17,19]

    if idx_species==1:
        #indices=np.arange(0,18,1)
        #print(Possible_J[18],Possible_J[19])
        indices_Js=[18,19]
        indices_Js_mice=[]#leave it empty
        
        #indices=np.arange(0,20,1)
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]
     
    for idx_moment in np.arange(5,7,1):
        clr=colors[idx_species]
        data_y_vs_J=np.zeros(len(Possible_J))
        
        for idx_J in range(len(Possible_J)):
            mask_cases=(sim_species==idx_species)&(sim_idx_J==idx_J)
            data_x=sim_param_all[mask_cases,12]
            if idx_moment==5:
                data_y=moments_of_r_sim_all[mask_cases,4]/moments_of_r_sim_all[mask_cases,3]**2
                panel=axs[0]
                
            if idx_moment==6:
                data_y=moments_of_r_sim_all[mask_cases,1]
                panel=axs[1]

            

            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

            
        for idx_J in indices_Js:
            mask_cases=(sim_species_Js==idx_species)&(sim_idx_J_Js==idx_J)
            data_x=sim_param_all_Js[mask_cases,12]
            if idx_moment==5:
                data_y=moments_of_r_sim_all_Js[mask_cases,4]/moments_of_r_sim_all_Js[mask_cases,3]**2
                
            if idx_moment==6:
                data_y=moments_of_r_sim_all_Js[mask_cases,1]

            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

        for idx_J in indices_Js_mice:
            mask_cases=(sim_species_Js_mice==idx_species)&(sim_idx_J_Js_mice==idx_J)
            data_x=sim_param_all_Js_mice[mask_cases,12]
            if idx_moment==5:
                data_y=moments_of_r_sim_all_Js_mice[mask_cases,4]/moments_of_r_sim_all_Js_mice[mask_cases,3]**2
                

            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

            
            
        panel.plot(Possible_J[indices]*10**3,data_y_vs_J[indices],c=clr,ls='-')
 

        if idx_moment==6:
            panel.plot(Possible_J[indices]*10**3,results_stc[idx_species][:,1][indices]-results_stc[idx_species][:,0][indices],c=clr,ls=':')
        if idx_moment!=6:
            panel.plot(Possible_J[indices]*10**3,results_stc[idx_species][:,idx_moment][indices],c=clr,ls=':')

        
    for idx_case in [0,1]:
        data_y_vs_J=np.zeros(len(Possible_J))
        for idx_J in range(len(Possible_J)):
            mask_cases=(sim_species==idx_species)&(sim_idx_J==idx_J)
    
            data_x=sim_param_all[mask_cases,12]
            if idx_case==0:
                data_y=np.abs(sim_curr_tot/sim_curr_E)[mask_cases,]
                clr='k'
            if idx_case==1:
                data_y=np.abs(sim_curr_opto/sim_curr_E)[mask_cases,]
                clr=['c','m'][idx_species]

            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

            
        for idx_J in indices_Js:
            mask_cases=(sim_species_Js==idx_species)&(sim_idx_J_Js==idx_J)
            
            data_x=sim_param_all_Js[mask_cases,12]
            if idx_case==0:
                data_y=np.abs(sim_curr_tot_Js/sim_curr_E_Js)[mask_cases,]
                clr='k'
            if idx_case==1:
                data_y=np.abs(sim_curr_opto_Js/sim_curr_E_Js)[mask_cases,]
                clr=['c','m'][idx_species]

            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])
         
        idx_moment=5
        idx_plot=2+idx_case
        if idx_case==0:
            axs[idx_plot].plot(Possible_J[indices]*10**3,data_y_vs_J[indices],c=clr,ls='-') 
            axs[idx_plot].plot(Possible_J[indices]*10**3,results_stc[idx_species][:,idx_moment+1+idx_case][indices],
                               c=clr,ls=':')
        if idx_case==1:
            axs[idx_plot].plot(Possible_J[indices]*10**3,data_y_vs_J[indices],c=clr,ls='-',label='unstructured model') 
            axs[idx_plot].plot(Possible_J[indices]*10**3,results_stc[idx_species][:,idx_moment+1+idx_case][indices],
                               c=clr,ls=':',label='structured model')


        axs[idx_plot].set_xscale('log')
        axs[idx_plot].set_yscale('log', )
        axs[idx_plot].set_xlim([0.01,1])
        axs[idx_plot].set_xlabel(r'$J$ (mV)')


for idx in [2,3,]:
    axs[idx].axis([0.01,1,0.002,2]);

    

      
best_J=[best_J_unstruct,best_J_struct]
for idx_species in [1]:
    for idx in range(4):
        for idx_model in [0,1]:
            axs[idx+0*idx_species].axvline(x=best_J[idx_model][idx_species]*10**3,
                                           ls=['-',':'][idx_model],c=['c','m'][idx_species])
    
    
axs[2].set_ylabel(r'Balance index $\beta$');
axs[3].set_ylabel(r'Optogenetic/excitatory input');
     
'''
fig.legend(bbox_to_anchor=(0.95, .3))

for idx in [7]:
    fig.delaxes(axs[idx])
'''
plt.tight_layout()
fig.set_size_inches(1.875*cols,1.875*rows)
pic_name='Supp_EX_Figure_6.pdf'
fig.savefig(pic_name,format='pdf',bbox_inches='tight', dpi=300)
pic_name='Supp_EX_Figure_6.png'
fig.savefig(pic_name,format='png',bbox_inches='tight', dpi=300)

# %%
idx_cnt_to_plot=-3

rows=2
cols=4

colors=['c','m']
fig, axs = plt.subplots(rows,cols, figsize=(2.5*cols,2.*rows), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.5)
axs = axs.ravel()


axs[0].text(-.2, 1.1,'A', transform=axs[0].transAxes,fontsize=8, fontweight='bold', va='top', ha='right');
axs[2].text(-.2, 1.1,'B', transform=axs[2].transAxes,fontsize=8, fontweight='bold', va='top', ha='right');
axs[6].text(-.2, 1.1,'C', transform=axs[6].transAxes,fontsize=8, fontweight='bold', va='top', ha='right');

for idx_species in range(2):
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]


    for idx_moment in [0,4,5]:
        if (idx_moment==0):
            idx_row=0
            ccc=['c','m'][idx_species]
            ymin=[0,-10][idx_species]
            ymax=[20,60][idx_species]
            m,sem=dataset[1,:,0]-dataset[0,:,0],np.sqrt(dataset[1,:,1]**2+dataset[0,:,1]**2)  

        if (idx_moment==4):
            idx_row=0
            ccc=['b','r'][idx_species]
            ymin=[0,-10][idx_species]
            ymax=[20,60][idx_species]
            m,sem=dataset[idx_moment,:,0],dataset[idx_moment,:,1]

        if (idx_moment==5):
            idx_row=1
            ccc=['c','m'][idx_species]
            ymin=-0.75
            ymax=0.35
                     
            m,sem=dataset[idx_moment,:,0],dataset[idx_moment,:,1]
            
            
        data_y=np.mean(m[idx_cnt_to_plot::])*np.ones(len(Possible_J))
        data_e=np.mean(sem[idx_cnt_to_plot::])*np.ones(len(Possible_J))
        axs[cols*idx_row+idx_species].plot(Possible_J*10**3,data_y,
                                           lw=3,c=ccc,
                                           )
        axs[cols*idx_row+idx_species].fill_between(Possible_J*10**3,data_y-data_e,data_y+data_e,
                                                 color=ccc,alpha=0.2)
    
        axs[cols*idx_row+idx_species].set_xscale('log')
        axs[cols*idx_row+idx_species].axis([0.01,1,ymin,ymax])

    axs[cols*idx_row+idx_species].axhline(y=0,ls='--',c='k')
    #axs[cols*3+idx_species].set_xlabel(r'$J$ (mV)')
    axs[cols*0+idx_species].set_title(['Mice','Monkeys'][idx_species])
    axs[cols*0+2+idx_species].set_title(['Mice','Monkeys'][idx_species])
    if idx_species==0:
        axs[cols*0].set_ylabel('$\Delta$rate (spk/s)')
        axs[cols*1].set_ylabel(r'$\rho$')
            
        
#indices=np.concatenate((np.arange(0,17,1),np.arange(19,20,1)))
#indices=np.concatenate((np.arange(0,16,1),np.arange(17,20,1)))
#indices=np.concatenate((np.arange(0,16,1),np.arange(17,20,1)))
indices=np.arange(0,20,1)

for idx_species in [0,1]:
    if idx_species==0:
        #indices=np.concatenate((np.arange(0,15,1),np.arange(16,19,1)))
        #indices=np.concatenate((np.arange(0,17,1),np.arange(18,19,1)))
        #print(Possible_J[15],Possible_J[17],Possible_J[19])
        indices_Js=[15,17,19]

    if idx_species==1:
        #indices=np.arange(0,18,1)
        #print(Possible_J[18],Possible_J[19])
        indices_Js=[18,19]

        #indices=np.arange(0,20,1)
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]
     
    for idx_moment in [1,4,5]:
        data_y_vs_J=np.zeros(len(Possible_J))
        
        for idx_J in range(len(Possible_J)):
            mask_cases=(sim_species==idx_species)&(sim_idx_J==idx_J)
            data_x=sim_param_all[mask_cases,12]
            if idx_moment==1:
                data_y=moments_of_r_sim_all[mask_cases,idx_moment]
                idx_plot=cols*0+idx_species
                clr=['c','m'][idx_species]

            if idx_moment==4:
                data_y=moments_of_r_sim_all[mask_cases,3]
                idx_plot=cols*0+idx_species
                clr=['b','r'][idx_species]

            if idx_moment==5:
                data_y=moments_of_r_sim_all[mask_cases,4]/moments_of_r_sim_all[mask_cases,3]**2
                idx_plot=cols*1+idx_species
                clr=['c','m'][idx_species]


            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

            
        for idx_J in indices_Js:
            mask_cases=(sim_species_Js==idx_species)&(sim_idx_J_Js==idx_J)
            data_x=sim_param_all_Js[mask_cases,12]
            if idx_moment==1:
                data_y=moments_of_r_sim_all_Js[mask_cases,idx_moment]
                idx_plot=cols*0+idx_species
                clr=['c','m'][idx_species]

            if idx_moment==4:
                data_y=moments_of_r_sim_all_Js[mask_cases,3]
                idx_plot=cols*0+idx_species
                clr=['b','r'][idx_species]

            if idx_moment==5:
                data_y=moments_of_r_sim_all_Js[mask_cases,4]/moments_of_r_sim_all_Js[mask_cases,3]**2
                idx_plot=cols*1+idx_species
                clr=['c','m'][idx_species]


            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

        axs[idx_plot].plot(Possible_J[indices]*10**3,data_y_vs_J[indices],c=clr,ls='-',label='unstructured')
        axs[idx_plot].set_xlim([0.01,1])
        axs[idx_plot].set_xlabel(r'$J$ (mV)')


        if idx_moment==1:
            axs[idx_plot].plot(Possible_J[indices]*10**3,results_stc[idx_species][:,idx_moment][indices]-results_stc[idx_species][:,0][indices],c=clr,ls=':',label='structured')
        if idx_moment>1:
            axs[idx_plot].plot(Possible_J[indices]*10**3,results_stc[idx_species][:,idx_moment][indices],c=clr,ls=':',label='structured')
                
        
        
    for idx_case in [0,1]:
        data_y_vs_J=np.zeros(len(Possible_J))
        for idx_J in range(len(Possible_J)):
            mask_cases=(sim_species==idx_species)&(sim_idx_J==idx_J)
    
            data_x=sim_param_all[mask_cases,12]
            if idx_case==0:
                data_y=np.abs(sim_curr_tot/sim_curr_E)[mask_cases,]
                clr='k'
            if idx_case==1:
                data_y=np.abs(sim_curr_opto/sim_curr_E)[mask_cases,]
                clr=['c','m'][idx_species]

            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

            
        for idx_J in indices_Js:
            mask_cases=(sim_species_Js==idx_species)&(sim_idx_J_Js==idx_J)
            
            data_x=sim_param_all_Js[mask_cases,12]
            if idx_case==0:
                data_y=np.abs(sim_curr_tot_Js/sim_curr_E_Js)[mask_cases,]
                clr='k'
            if idx_case==1:
                data_y=np.abs(sim_curr_opto_Js/sim_curr_E_Js)[mask_cases,]
                clr=['c','m'][idx_species]

            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])
            
        idx_plot=cols*(idx_case)+2+idx_species
        axs[idx_plot].plot(Possible_J[indices]*10**3,data_y_vs_J[indices],c=clr,ls='-',label='unstructured') 
        axs[idx_plot].plot(Possible_J[indices]*10**3,results_stc[idx_species][:,idx_moment+1+idx_case][indices],
                           c=clr,ls=':',label='structured')


        axs[idx_plot].set_xscale('log')
        axs[idx_plot].set_yscale('log', )
        axs[idx_plot].set_xlim([0.01,1])
        axs[idx_plot].set_xlabel(r'$J$ (mV)')


for idx in [2,3,]:
    axs[idx].axis([0.01,1,0.003,3]);
    axs[idx+cols].axis([0.01,1,0.001,1]);

    

      
best_J=[best_J_unstruct,best_J_struct]
for idx_species in range(2):
    for idx in range(4):
        for idx_model in [0,1]:
            axs[2*idx+idx_species].axvline(x=best_J[idx_model][idx_species]*10**3,
                                           ls=['-',':'][idx_model],c=['c','m'][idx_species])
    
    
axs[2].set_ylabel(r'Balance index $\beta$');
axs[6].set_ylabel(r'Optogenetic/excitatory input');

#axs[0].legend(loc='lower right')
#axs[1].legend(loc='lower right')

axs[2].legend(loc='lower left')
#axs[6].legend(loc='lower left')



plt.tight_layout()
fig.set_size_inches(1.875*cols,1.875*rows)
pic_name='Figure_6.pdf'
fig.savefig(pic_name,format='pdf',bbox_inches='tight', dpi=300)
pic_name='Figure_6.png'
fig.savefig(pic_name,format='png',bbox_inches='tight', dpi=300)

# %%
sim_param_all_Js[mask_cases,12]
# Out:
# array([47.68, 47.68, 47.68, 47.68, 47.68, 47.68, 47.68, 47.68, 47.68,
#        47.68, 47.68, 47.68, 47.68, 47.68, 47.68, 47.68, 47.68, 47.68,
#        47.68, 47.68])

# %%
idx_moment=1
idx_species=0
idx_J=15
mask_cases=(sim_species_Js==idx_species)&(sim_idx_J_Js==idx_J)
data_x=sim_param_all_Js[mask_cases,12]
if idx_moment==1:
    data_y=moments_of_r_sim_all_Js[mask_cases,idx_moment]
    clr=['c','m'][idx_species]

if idx_moment==4:
    data_y=moments_of_r_sim_all_Js[mask_cases,3]
    clr=['b','r'][idx_species]

if idx_moment==5:
    data_y=moments_of_r_sim_all_Js[mask_cases,4]/moments_of_r_sim_all_Js[mask_cases,3]**2
    clr=['c','m'][idx_species]

# %%
idx_moment=3
moments_of_r_sim_all_Js[mask_cases,idx_moment]
# Out:
# array([ 7.55,  8.3 ,  8.99,  6.74,  8.81,  8.39,  7.98,  9.16,  9.74,
#         5.96,  9.15,  7.57,  8.96,  8.56, 10.8 ,  8.88,  7.16,  8.12,
#         9.56,  8.61])

# %%
np.log10(sim_param_all_Js[mask_cases,11])
# Out:
# array([-3.42, -3.42, -3.42, -3.42, -3.42, -3.42, -3.42, -3.42, -3.42,
#        -3.42, -3.42, -3.42, -3.42, -3.42, -3.42, -3.42, -3.42, -3.42,
#        -3.42, -3.42])

# %%
'''
sim_param_all=results[:,0:15]
moments_of_r_sim_all=results[:,15:20]
sim_convergence_all=results[:,20:24]
sim_decay_all=results[:,26]/results[:,27]
sim_species=results[:,28]
sim_idx_J=results[:,29]

Possible_Tmax_over_tau_E=np.unique(sim_param_all[:,14])
Possible_sigma_Lambda_over_Lambda=np.unique(sim_param_all[:,10])
Possible_r_X=np.unique(sim_param_all[:,12])
Possible_J=np.unique(sim_param_all[:,11])

'''

# %%
idx_cnt_to_plot=-3

rows=6
cols=2

colors=['c','m']
fig, axs = plt.subplots(rows,cols, figsize=(2.5*cols,2.*rows), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=.5)
axs = axs.ravel()

for idx_species in range(2):
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]
         
    for idx_moment in range(6):
        if idx_moment<2:
            idx_row=0
            ccc=['k',colors[idx_species]][idx_moment]
            ymin=0
            ymax=[25,80][idx_species]
            
        if (idx_moment>=2)&(idx_moment<4):
            idx_row=1
            ccc=['k',colors[idx_species]][idx_moment-2]
            ymin=0
            #ymax=[20,60][idx_species]
            ymax=[20,70][idx_species]
         
        if (idx_moment==4):
            idx_row=2
            ccc=colors[idx_species]
            ymin=0
            ymax=[20,60][idx_species]
         
        if (idx_moment==5):
            idx_row=3
            ccc=colors[idx_species]
            ymin=-0.75
            ymax=0.25
                     
        m,sem=dataset[idx_moment,:,0],dataset[idx_moment,:,1]
        data_y=np.mean(m[idx_cnt_to_plot::])*np.ones(len(Possible_J))
        data_e=np.mean(sem[idx_cnt_to_plot::])*np.ones(len(Possible_J))
        axs[cols*idx_row+idx_species].scatter(Possible_J*10**3,data_y,
                                           facecolors='none', s=10,edgecolors=ccc,marker='o'
                                           )
        axs[cols*idx_row+idx_species].fill_between(Possible_J*10**3,data_y-data_e,data_y+data_e,
                                                 color=ccc,alpha=0.2)
    
        axs[cols*idx_row+idx_species].set_xscale('log')
        axs[cols*idx_row+idx_species].axis([0.01,1,ymin,ymax])
    axs[cols*idx_row+idx_species].axhline(y=0,ls='--',c='k')
    #axs[cols*3+idx_species].set_xlabel(r'$J$ (mV)')
    axs[cols*0+idx_species].set_title(['Mice','Monkeys'][idx_species])
    if idx_species==0:
        axs[cols*0].set_ylabel('Mean rate\n(spk/s)')
        axs[cols*1].set_ylabel('Std rate\n(spk/s)')
        axs[cols*2].set_ylabel('Std $\Delta$rate\n(spk/s)')
        axs[cols*3].set_ylabel(r'$\rho$')
        

for idx_species in [0,1]:
    
    dataset=dataset_both_species[idx_species]
    Con=Con_both_species[idx_species]
    nCon=nCon_both_species[idx_species]
     
    for idx_moment in range(6):
        clr=color[idx_species]

        data_y_vs_J=np.zeros(len(Possible_J))
        for idx_J in range(len(Possible_J)):
            mask_cases=(sim_species==idx_species)&(sim_idx_J==idx_J)
            data_x=sim_param_all[mask_cases,12]

            if idx_moment==0:
                data_y=moments_of_r_sim_all[mask_cases,0]
                idx_plot=cols*0+idx_species
                clr='k'
            if idx_moment==1:
                data_y=moments_of_r_sim_all[mask_cases,0]+moments_of_r_sim_all[mask_cases,1]
                idx_plot=cols*0+idx_species
            if idx_moment==2:
                data_y=moments_of_r_sim_all[mask_cases,2]
                idx_plot=cols*1+idx_species
                clr='k'
            if idx_moment==3:
                data_y=np.sqrt(moments_of_r_sim_all[mask_cases,2]**2
                               +moments_of_r_sim_all[mask_cases,3]**2
                               +2*moments_of_r_sim_all[mask_cases,4])
                idx_plot=cols*1+idx_species
            if idx_moment==4:
                data_y=moments_of_r_sim_all[mask_cases,3]
                idx_plot=cols*2+idx_species

            if idx_moment==5:
                data_y=moments_of_r_sim_all[mask_cases,4]/moments_of_r_sim_all[mask_cases,3]**2
                idx_plot=cols*3+idx_species


            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

        axs[idx_plot].plot(Possible_J*10**3,data_y_vs_J,c=clr,ls='-')


    
    for idx_case in [0,1]:
        data_y_vs_J=np.zeros(len(Possible_J))
        for idx_J in range(len(Possible_J)):
            mask_cases=(sim_species==idx_species)&(sim_idx_J==idx_J)
    
            data_x=sim_param_all[mask_cases,12]
            if idx_case==0:
                data_y=np.abs(sim_curr_tot/sim_curr_E)[mask_cases,]
                clr='k'
            if idx_case==1:
                data_y=np.abs(sim_curr_opto/sim_curr_E)[mask_cases,]
                clr=color[idx_species]

            data_y_med=np.zeros((len(np.unique(data_x)),3))
            for idx in range(len(np.unique(data_x))):
                mask_x=data_x==np.unique(data_x)[idx]
                data_y_med[idx,0]=np.mean(data_y[mask_x])
                data_y_med[idx,1]=stats.sem(data_y[mask_x])
            data_y_vs_J[idx_J]=np.mean(data_y_med[idx_cnt_to_plot::,0])

            
        idx_plot=cols*(idx_case+4)+idx_species
        axs[idx_plot].plot(Possible_J*10**3,data_y_vs_J,c=clr,ls='-') 

        axs[idx_plot].set_xscale('log')
        axs[idx_plot].set_yscale('log', )
        axs[idx_plot].set_xlim([0.01,1])
        axs[idx_plot].set_xlabel(r'$J$ (mV)')


axs[4*cols].set_ylabel(r'Balance index $\beta$');
axs[4*cols].set_ylim([0.001,1]);
axs[4*cols+1].set_ylim([0.001,1]);
axs[5*cols].set_ylabel(r'Optogenetic/excitatory input');
axs[5*cols].set_ylim([0.001,1]);
axs[5*cols+1].set_ylim([0.001,1]);

plt.tight_layout()
fig.set_size_inches(1.875*cols,1.875*rows)
pic_name='Figure_6_revision.pdf'
fig.savefig(pic_name,format='pdf',bbox_inches='tight', dpi=300)
pic_name='Figure_6_revision.png'
fig.savefig(pic_name,format='png',bbox_inches='tight', dpi=300)
